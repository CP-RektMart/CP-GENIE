# %%
from langchain_community.document_loaders import DirectoryLoader

path = "../data/processed/text"
loader = DirectoryLoader(path, glob="**/*.txt", show_progress=True)
docs = loader.load()
# Out:
# ...
# 100%|██████████| 459/459 [00:06<00:00, 66.26it/s]

# %%
docs[:10]
# Out:
# [Document(metadata={'source': '../data/processed/text/blog__archives__25292__109683c0.txt'}, page_content='🥳เตรียมตัวให้พร้อม🥳กับกิจกรรมสุดพิเศษ ในงาน Friday Activities (สัปดาห์ที่ 10) Tweet March 8, 2024 ข่าวเก่า Tag: CEDT , CP , CPCU , CUCA , วิศวะคอมจุฬา 🥳เตรียมตัวให้พร้อม🥳 กับกิจกรรมสุดพิเศษ ในงาน Friday Activities (สัปดาห์ที่ 10) ที่จะพาเหล่านิสิตภาควิชาวิศวกรรมคอมพิวเตอร์ ร่วมรับฟังพร้อมเรียนรู้ประสบการณ์ตรงจากสถานประกอบการ เพื่อเพิ่มพูนทักษะและประสบการณ์ที่จำเป็นในการทำงานด้านคอมพิวเตอร์ โดยนิสิตสามารถเลือกเข้าร่วมกิจกรรมตามความสนใจได้ 📌วัน ศุกร์ ที่ 15 มีนาคม 2567📌 พบกับ 3 สถานประกอบการ ดังนี้ 🏬 บริษัท เดอะเรดคาร์บอน จำกัด 🏬 เตรียมพบกับเคล็ดลับในการสร้างและนำเสนองานที่มีประสิทธิภาพ พร้อมเทคนิคการที่จะเป็นนักเล่าเรื่องที่ดีและสร้างสรรค์การเล่าเรื่อง\n\nเวลา 13:00\n\n16:00 น.\n\nณ. อาคารวิศวฯ 100 ปี ชั้น 4 ห้อง 401 คณะวิศวกรรมศาสตร์ จุฬาลงกรณ์มหาวิทยาลัย รับจำกัด 40 ที่นั่งเท่านั้น 🏢 บริษัท ซอฟต์สแควร์ อินเตอร์เนชั่นแนล จำกัด 🏢 เตรียมตัวให้พร้อมกับ Workshop HTML เพื่อแสดงผลข้อม
# ...

# %%
import os
os.environ["GOOGLE_API_KEY"] = "..."  # From https://ai.google.dev/

# %%
config = {
    "model": "gemini-2.0-flash-lite",  # or other model IDs
    "temperature": 0.4,
    "max_tokens": None,
    "top_p": 0.8,
}

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

# Choose the appropriate import based on your API:
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_vertexai import ChatVertexAI

# Initialize with Google AI Studio
generator_llm = LangchainLLMWrapper(ChatGoogleGenerativeAI(
    model=config["model"],
    temperature=config["temperature"],
    max_tokens=config["max_tokens"],
    top_p=config["top_p"],
))

# %%
# Google AI Studio Embeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings

generator_embeddings = LangchainEmbeddingsWrapper(GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-exp-03-07",  # Google's text embedding model 
    task_type="retrieval_document"  # Optional: specify the task type
))

# %%
from ragas.testset import TestsetGenerator

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=10)
# Out:
# ...
# Applying HeadlinesExtractor:   1%|▏         | 4/283 [00:01<01:20,  3.49it/s]Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ...
# Applying HeadlinesExtractor:   4%|▎         | 10/283 [00:02<00:30,  8.98it/s]Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ...

# %%
dataset
# Out:
# Testset(samples=[TestsetSample(eval_sample=SingleTurnSample(user_input='What are the career paths available for graduates of the วิศวกรรมคอมพิวเตอร์ program?', retrieved_contexts=None, reference_contexts=['หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอมพิวเตอร์และเทคโนโลยีดิจิทัล Bachelor of Engineering Program in Computer Engineering and Digital Technology ปีการศึกษา 2566 1.สภาพปัญหาและเหตุผลความจำเป็น ปัจจุบัน ความก้าวหน้าทางด้านเทคโนโลยีคอมพิวเตอร์มีความก้าวหน้าอย่างรวดเร็วมาก และมีผลกระทบต่อธุรกิจ อุตสาหกรรม และสังคม อย่างรุนแรงและหลีกเลี่ยงไม่ได้ ธุรกิจต้องมีการปรับตัวอย่างรวดเร็วและนำเทคโนโลยีคอมพิวเตอร์มาใช้เพื่อรองรับความต้องการของลูกค้าที่เปลี่ยนไป ระบบเศรษฐกิจที่สามารถขับเคลื่อนไปได้ต้องมีบุคลากรทางเทคโนโลยีคอมพิวเตอร์ที่มีศักยภาพจำนวนมาก โดยเฉพาะอย่างยิ่ง ความสามารถทั้งด้านระบบคอมพิวเตอร์และเทคโนโลยีดิจิทัล ซึ่งประกอบด้วย ฮาร์ดแวร์ ซอฟต์แวร์ ข้อมูล เครือข่าย และด้านปัญญาประดิษฐ์ จึงจะสามารถรองรับการเปลี่ยนแปลงและความต้องการของภาคธุรกิจและอุตสาหกรรมได้อย่างทันท่วงที ประกอบก
# ...

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0  What are the career paths available for gradua...
# 1  As a Computer Engineering student at Chulalong...
# 2  In what ways does the สภาอุตสาหกรรม collaborat...
# 3  Could you please clarify the availability of c...
# 4  What is the link to the admission information ...
# 5  As a computer engineering student, what are so...
# 6  As a Computer Engineering student, Natcha is i...
# 7  As a computer engineering student, what are th...
# 8  As a faculty member at Chulalongkorn Universit...
# 9  As a Computer Engineering student, what are th...
#
#                                   reference_contexts  \
# 0  [หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมค...
# 1  [4.1.3 รายวิชา **รายวิชาที่ให้เกรดเป็น S/U 4.1...
# 2  [แผนการศึกษา วิชาที่ให้เกรดเป็น S/U ปีที่ 1 ภา...
# 3  [โครงสร้างหลักสูตร หลักสูตรนี้ มีจำนวนหน่วยกิต...
# 4  [หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมค...
# 5  [<1-hop>\n\nรายนามคณาจารย์ รายละเอียด เว็บไซต์...
# ...

# %%
dataset.to_jsonl(path="testset.jsonl")
dataset.to_csv(path="testset.csv")

# %%
generator
# Out:
# TestsetGenerator(llm=LangchainLLMWrapper(langchain_llm=ChatGoogleGenerativeAI(...)), embedding_model=LangchainEmbeddingsWrapper(embeddings=GoogleGenerativeAIEmbeddings(...)), knowledge_graph=KnowledgeGraph(nodes: 740, relationships: 101), persona_list=[Persona(name='Natcha Techawong', role_description='A Computer Engineering student at Chulalongkorn University, seeking practical experience and career opportunities in the digital technology field.'), Persona(name='Pattama Boonchu', role_description='A university student seeking hands-on experience in the banking industry, looking for internship opportunities to enhance her resume and career prospects.'), Persona(name='Professor Anya Sharma', role_description="A faculty member at Chulalongkorn University's Faculty of Engineering, possibly involved in Computer Engineering or related programs, interested in student achievements and industry collaborations.")])

# %%
llm2 = LangchainLLMWrapper(ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-preview-04-17",
    temperature=config["temperature"],
    max_tokens=config["max_tokens"],
    top_p=config["top_p"],
))

generator.llm = llm2

# %%
generator.knowledge_graph.save(path="kg.json")

# %%
dataset2 = generator.generate(testset_size=50)
# Out:
# Generating Scenarios:   0%|          | 0/2 [00:00<?, ?it/s]Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ].
# ...
